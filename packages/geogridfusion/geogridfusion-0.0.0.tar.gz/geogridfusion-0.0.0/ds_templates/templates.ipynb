# %%
import dask.array as da
import numpy as np
import xarray as xr

import geogridfusion
import geogridfusion.templates
# pvgis_template = xr.open_dataset("pvgis-sample-data.nc", engine="h5netcdf")

# # or should we call this when required instead of saving
# xr.Dataset(
#     data_vars={
#         name: (("gid", "time"), np.empty((0, len(pvgis_template.time)))) 
#         for name in list(pvgis_template.data_vars)
#     },
#     coords={
#         "time": pvgis_template.time.values,
#         "gid": np.array([]),
#     }
# ).to_netcdf("pvgis-tmy-template.nc", engine="h5netcdf")

# %%
xr.open_dataset("pvgis-tmy-template.nc")

# %%
geogridfusion.templates.PVGIS_TMY_TEMPLATE
# Out:
# <xarray.Dataset> Size: 70kB
# Dimensions:                 (gid: 0, time: 8760)
# Coordinates:
#   * time                    (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12...
#   * gid                     (gid) float64 0B
# Data variables: (12/15)
#     temp_air                (gid, time) float64 0B
#     relative_humidity       (gid, time) float64 0B
#     ghi                     (gid, time) float64 0B
#     dni                     (gid, time) float64 0B
#     dhi                     (gid, time) float64 0B
#     IR(h)                   (gid, time) float64 0B
#     ...                      ...
#     latitude                (gid) float64 0B
#     longitude               (gid) float64 0B
#     irradiance_time_offset  (gid) float64 0B
#     altitude                (gid) int64 0B
#     wind_height             (gid) float64 0B
#     Source                  (gid) <U5 0B

# %%
geogridfusion.templates.COMB_TMY_TEMPLATE
# Out:
# <xarray.Dataset> Size: 70kB
# Dimensions:            (gid: 0, time: 8760)
# Coordinates:
#   * time               (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12-31T2...
#   * gid                (gid) float64 0B
# Data variables: (12/14)
#     temp_air           (gid, time) float64 0B
#     relative_humidity  (gid, time) float64 0B
#     ghi                (gid, time) float64 0B
#     dni                (gid, time) float64 0B
#     dhi                (gid, time) float64 0B
#     IR(h)              (gid, time) float64 0B
#     ...                 ...
#     pressure           (gid, time) float64 0B
#     latitude           (gid) float64 0B
#     longitude          (gid) float64 0B
#     altitude           (gid) int64 0B
#     wind_height        (gid) float64 0B
#     Source             (gid) <U5 0B

# %%
geogridfusion.templates.COMB_TMY_TEMPLATE
# Out:
# <xarray.Dataset> Size: 70kB
# Dimensions:            (gid: 0, time: 8760)
# Coordinates:
#   * time               (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12-31T2...
#   * gid                (gid) int32 0B
# Data variables: (12/14)
#     temp_air           (gid, time) float64 0B
#     relative_humidity  (gid, time) float64 0B
#     ghi                (gid, time) float64 0B
#     dni                (gid, time) float64 0B
#     dhi                (gid, time) float64 0B
#     IR(h)              (gid, time) float64 0B
#     ...                 ...
#     pressure           (gid, time) float64 0B
#     latitude           (gid) float64 0B
#     longitude          (gid) float64 0B
#     altitude           (gid) float64 0B
#     wind_height        (gid) int64 0B
#     Source             (gid) <U5 0B
