# %% [markdown]
# ### Configure Input Data Source

# %%
from tecton_gen_ai.testing import set_dev_mode

set_dev_mode()

# %%
import pandas as pd
import pathlib

from tecton import Entity
from tecton.types import Field, String
from tecton_gen_ai.testing import make_local_source, set_dev_mode


df = pd.read_json(pathlib.Path().parent / "output.jsonl", lines=True)
src = make_local_source(
    "call_transcripts",
    df,
    description="Call transcripts",
)

transcript_id = Entity(
    name="transcript", join_keys=[Field(name="transcript_id", dtype=String)]
)

# %% [markdown]
# ## Create LLM Extracted Feature Views

# %% [markdown]
# ### Define Target Schema

# %%
import pydantic
from enum import Enum
from typing import Literal
from datetime import datetime


class TranscriptTopic(Enum):
    POLICY_COVERAGE = "policy-coverage"
    CLAIMS_PROCESS = "claims-process"
    DISCOUNTS = "discounts"
    RENEWAL = "renewal"
    CLAIMS_FILING = "claims-filing"
    PREMIUMS = "premiums"
    POLICY_CHANGES = "policy-changes"
    COVERAGE = "coverage"
    ACCIDENT = "accident"
    OTHER = "other"


class TranscriptFeatures(pydantic.BaseModel):
    summary: str = pydantic.Field(description="Summary of the conversation")
    topic: TranscriptTopic
    sentiment: Literal["positive", "neutral", "negative"]

# %%
from tecton_gen_ai.extraction import llm_extraction

extraction_config = [
    {"model": "openai/gpt-4o", "column": "conversation", "schema": TranscriptFeatures},
]
fv = llm_extraction(src, extraction_config, entities=[transcript_id])

# %%
df = fv.get_features_in_range(
    start_time=datetime(2024, 1, 1), end_time=datetime(2024, 1, 3)
).to_pandas()
df
# Out:
#     transcript_id                                            summary  \
# 0   pabc-d115d4e2  Alex Johnson inquires about customer service h...
# 1   pabc-33d5c4e5  John Doe called Insured to inquire about his p...
# 2   pabc-cfb69c46  The customer, John Doe, is frustrated with the...
# 3   pabc-07502e3c  John Doe called to inquire about the increase ...
# 4   pabc-19fc9565  Emily Carter called to report a minor accident...
# 5   pabc-d5e9249d  A customer named John Doe is seeking assistanc...
# 6   pabc-3a2202de  A customer named Jane is seeking assistance wi...
# 7   pabc-e59c36cb  John Peterson is experiencing issues filing a ...
# 8   pabc-223b170b  Alice Smith calls Insured to inquire about her...
# 9   pabc-9d3e0732  The customer, John, seeks assistance in filing...
# 10  pabc-84bc62bd  Alexa Johnson inquires about the customer serv...
# 11  pabc-93b1a900  John Doe inquired about car insurance coverage...
# 12  pabc-ddf2373e  John Doe is calling about his renewal process ...
# 13  pabc-31277387  John Doe called about his car insurance policy...
# 14  pabc-51e528c8  Alice Green calls Insured to file a claim for ...
# 15  pabc-102841ad  John Doe called regarding his car insurance po...
# 16  pabc-d54a0d40  John Doe contacted the agent to update his car...
# 17  pabc-f7d3b8e3  John seeks clarification on his car insurance ...
# 18  pabc-a772bb69  John Doe called Insured to inquire about the c...
# 19  pabc-f925e14b  Jane Doe contacted Insured's customer support ...
# 20  pabc-6d3245f5  John Doe inquired about the car insurance clai...
# 21  pabc-31864875  John Doe called Insured regarding a recent car...
# 22  pabc-ca0f5d02  John Doe is having difficulty filing a claim t...
# 23  pabc-728e9f2f  John Doe called to inquire about the accident ...
# 24  pabc-7fcbb25f  John Doe inquires about car insurance policy c...
# 25  pabc-21a23011  John Doe called to inquire about the procedure...
# 26  pabc-3e5ddf52  Alex Johnson calls to inquire about the renewa...
# 27  pabc-51d665e6  John Doe is frustrated with the coverage optio...
# 28  pabc-e16024c8  John Doe inquires about the claims process for...
# 29  pabc-898ad686  John Doe called Insured regarding the renewal ...
# 30  pabc-c9b9ad4f  John Doe called to inquire about his car insur...
# 31  pabc-ca67a466  John Doe called Insured to update his car insu...
# 32  pabc-a3bf23bf  John Doe inquired about the claims process wit...
# 33  pabc-d25e8ac3  The customer is having trouble filing a claim ...
# 34  pabc-4f0a259c  John Doe called Insured to inquire about the c...
# 35  pabc-e2633c41  John Doe calls Insured customer support to und...
# 36  pabc-d46f9455  John Doe inquired about the claims process for...
# 37  pabc-a7b661c7  Alice Smith contacted Insured to discuss issue...
# 38  pabc-c3ad4b2c  John Doe called Insured to make changes to his...
# 39  pabc-452f97b6  John Doe contacted his insurance company for g...
# 40  pabc-f1dcc749  Alex inquired about the factors influencing th...
# 41  pabc-23001eaa  John Doe called Insured customer support to in...
# 42  pabc-40921656  John Doe inquired about discounts and offers o...
# 43  pabc-7c87af3e  John Doe inquired about the claims process for...
# 44  pabc-a32c0fb7  John Doe called to make changes to his insuran...
# 45  pabc-2623fc63  Jane Doe calls to update her car insurance pol...
# 46  pabc-0bfda520  John Doe called about a delayed claim, which h...
# 47  pabc-ea8801cd  John Smith calls Insured customer support to i...
# 48  pabc-fe4f3c7c  Jane Doe inquires about how to file a claim th...
# 49  pabc-cfb8a4b7  Alice Johnson called to update her car insuran...
# 50  pabc-cbe4c4d9  John Doe called to update his car insurance po...
# 51  pabc-0987bb3f  John Doe faced issues renewing his car insuran...
# 52  pabc-33b50cc3  Emily Clarke inquired about the renewal proces...
# 53  pabc-318ceabe  John Doe seeks guidance after a car accident a...
# 54  pabc-adc89dfb  Customer John Doe is upset about the increased...
# 55  pabc-9ee7e1fe  John Doe is frustrated with the car insurance ...
# 56  pabc-5e49b43a  John Doe inquired about the increase in his ca...
# 57  pabc-4fd26579  Jane Doe called Insured for assistance in fili...
# 58  pabc-b679042c  John Doe inquired about car insurance coverage...
# 59  pabc-f3e37712  John Doe called Insured to inquire about the a...
#
#               topic sentiment               _valid_from  \
# 0             other  positive 2024-01-02 00:00:00+00:00
# 1          coverage  positive 2024-01-02 00:00:00+00:00
# 2           renewal  negative 2024-01-02 00:00:00+00:00
# 3          premiums  negative 2024-01-02 00:00:00+00:00
# 4     claims-filing  positive 2024-01-02 00:00:00+00:00
# 5     claims-filing  positive 2024-01-02 00:00:00+00:00
# 6     claims-filing  positive 2024-01-02 00:00:00+00:00
# 7     claims-filing  negative 2024-01-02 00:00:00+00:00
# 8          premiums  positive 2024-01-02 00:00:00+00:00
# 9     claims-filing  positive 2024-01-02 00:00:00+00:00
# 10            other  positive 2024-01-02 00:00:00+00:00
# 11  policy-coverage  positive 2024-01-02 00:00:00+00:00
# 12          renewal  negative 2024-01-02 00:00:00+00:00
# 13          renewal  positive 2024-01-02 00:00:00+00:00
# 14    claims-filing  positive 2024-01-02 00:00:00+00:00
# 15   claims-process  negative 2024-01-02 00:00:00+00:00
# 16   policy-changes  positive 2024-01-02 00:00:00+00:00
# 17  policy-coverage  negative 2024-01-02 00:00:00+00:00
# 18          renewal  positive 2024-01-02 00:00:00+00:00
# 19         accident  negative 2024-01-02 00:00:00+00:00
# 20   claims-process   neutral 2024-01-02 00:00:00+00:00
# 21   claims-process  negative 2024-01-02 00:00:00+00:00
# 22    claims-filing  negative 2024-01-02 00:00:00+00:00
# 23         accident  positive 2024-01-02 00:00:00+00:00
# 24  policy-coverage  positive 2024-01-02 00:00:00+00:00
# 25    claims-filing  positive 2024-01-02 00:00:00+00:00
# 26          renewal  positive 2024-01-02 00:00:00+00:00
# 27  policy-coverage  negative 2024-01-02 00:00:00+00:00
# 28   claims-process  positive 2024-01-02 00:00:00+00:00
# 29          renewal  negative 2024-01-02 00:00:00+00:00
# 30  policy-coverage  positive 2024-01-02 00:00:00+00:00
# 31   policy-changes  positive 2024-01-02 00:00:00+00:00
# 32   claims-process  positive 2024-01-02 00:00:00+00:00
# 33    claims-filing  negative 2024-01-02 00:00:00+00:00
# 34   claims-process  positive 2024-01-02 00:00:00+00:00
# 35         premiums  positive 2024-01-02 00:00:00+00:00
# 36   claims-process  positive 2024-01-02 00:00:00+00:00
# 37         coverage  negative 2024-01-02 00:00:00+00:00
# 38   policy-changes  positive 2024-01-02 00:00:00+00:00
# 39         accident  positive 2024-01-02 00:00:00+00:00
# 40         premiums  positive 2024-01-02 00:00:00+00:00
# 41            other  positive 2024-01-02 00:00:00+00:00
# 42        discounts  positive 2024-01-02 00:00:00+00:00
# 43   claims-process  positive 2024-01-02 00:00:00+00:00
# 44   policy-changes  positive 2024-01-02 00:00:00+00:00
# 45   policy-changes  positive 2024-01-02 00:00:00+00:00
# 46   claims-process  negative 2024-01-02 00:00:00+00:00
# 47    claims-filing  positive 2024-01-02 00:00:00+00:00
# 48    claims-filing  positive 2024-01-02 00:00:00+00:00
# 49   policy-changes  positive 2024-01-02 00:00:00+00:00
# 50   policy-changes  positive 2024-01-02 00:00:00+00:00
# 51          renewal   neutral 2024-01-02 00:00:00+00:00
# 52          renewal  positive 2024-01-02 00:00:00+00:00
# 53         accident   neutral 2024-01-02 00:00:00+00:00
# 54          renewal  negative 2024-01-02 00:00:00+00:00
# 55   claims-process  negative 2024-01-02 00:00:00+00:00
# 56         premiums  positive 2024-01-02 00:00:00+00:00
# 57    claims-filing  positive 2024-01-02 00:00:00+00:00
# 58         coverage  positive 2024-01-02 00:00:00+00:00
# 59         accident  positive 2024-01-02 00:00:00+00:00
#
#                    _valid_to
# 0  2024-01-03 00:00:00+00:00
# 1  2024-01-03 00:00:00+00:00
# 2  2024-01-03 00:00:00+00:00
# 3  2024-01-03 00:00:00+00:00
# 4  2024-01-03 00:00:00+00:00
# 5  2024-01-03 00:00:00+00:00
# 6  2024-01-03 00:00:00+00:00
# 7  2024-01-03 00:00:00+00:00
# 8  2024-01-03 00:00:00+00:00
# 9  2024-01-03 00:00:00+00:00
# 10 2024-01-03 00:00:00+00:00
# 11 2024-01-03 00:00:00+00:00
# 12 2024-01-03 00:00:00+00:00
# 13 2024-01-03 00:00:00+00:00
# 14 2024-01-03 00:00:00+00:00
# 15 2024-01-03 00:00:00+00:00
# 16 2024-01-03 00:00:00+00:00
# 17 2024-01-03 00:00:00+00:00
# 18 2024-01-03 00:00:00+00:00
# 19 2024-01-03 00:00:00+00:00
# 20 2024-01-03 00:00:00+00:00
# 21 2024-01-03 00:00:00+00:00
# 22 2024-01-03 00:00:00+00:00
# 23 2024-01-03 00:00:00+00:00
# 24 2024-01-03 00:00:00+00:00
# 25 2024-01-03 00:00:00+00:00
# 26 2024-01-03 00:00:00+00:00
# 27 2024-01-03 00:00:00+00:00
# 28 2024-01-03 00:00:00+00:00
# 29 2024-01-03 00:00:00+00:00
# 30 2024-01-03 00:00:00+00:00
# 31 2024-01-03 00:00:00+00:00
# 32 2024-01-03 00:00:00+00:00
# 33 2024-01-03 00:00:00+00:00
# 34 2024-01-03 00:00:00+00:00
# 35 2024-01-03 00:00:00+00:00
# 36 2024-01-03 00:00:00+00:00
# 37 2024-01-03 00:00:00+00:00
# 38 2024-01-03 00:00:00+00:00
# 39 2024-01-03 00:00:00+00:00
# 40 2024-01-03 00:00:00+00:00
# 41 2024-01-03 00:00:00+00:00
# 42 2024-01-03 00:00:00+00:00
# 43 2024-01-03 00:00:00+00:00
# 44 2024-01-03 00:00:00+00:00
# 45 2024-01-03 00:00:00+00:00
# 46 2024-01-03 00:00:00+00:00
# 47 2024-01-03 00:00:00+00:00
# 48 2024-01-03 00:00:00+00:00
# 49 2024-01-03 00:00:00+00:00
# 50 2024-01-03 00:00:00+00:00
# 51 2024-01-03 00:00:00+00:00
# 52 2024-01-03 00:00:00+00:00
# 53 2024-01-03 00:00:00+00:00
# 54 2024-01-03 00:00:00+00:00
# 55 2024-01-03 00:00:00+00:00
# 56 2024-01-03 00:00:00+00:00
# 57 2024-01-03 00:00:00+00:00
# 58 2024-01-03 00:00:00+00:00
# 59 2024-01-03 00:00:00+00:00

# %%
df.iloc[0]["summary"]
# Out:
# 'Alex Johnson inquires about customer service hours and learns that they are available from 8 AM to 8 PM, Monday to Friday, and 9 AM to 5 PM on Saturdays. These hours apply to both phone and in-person visits. For support outside these hours, options include email or online chat.'

# %%
df.iloc[0]
# Out:
# transcript_id                                        pabc-d115d4e2
# summary          Alex Johnson inquires about customer service h...
# topic                                                        other
# sentiment                                                 positive
# _valid_from                              2024-01-02 00:00:00+00:00
# _valid_to                                2024-01-03 00:00:00+00:00
# Name: 0, dtype: object

# %%
df.dtypes
# Out:
# transcript_id                 object
# summary                       object
# topic                         object
# sentiment                     object
# _valid_from      datetime64[us, UTC]
# _valid_to        datetime64[us, UTC]
# dtype: object
