# %% [markdown]
# ## Run a pipeline using a dask gateway cluster

# %% [markdown]
# This process will run the entire pipeline described in a configuration file using a dask gateway cluster (LocalCluster

# %% [markdown]
# ## Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline

# %% [markdown]
# ## Instantiate the Pipeline Class

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_client.yaml", verbose=2)
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:30:55 | Created LocalCluster with Client: http://127.0.0.1:8787/status

# %% [markdown]
# As you can see, when you instantiate the Pipeline class with this configuration file, a LocalCluster is created and you can access the dashboard in the link above.
#
# This occours because we have the following parameters in the configuration file, as you can see below:
#
# ```
# "n_jobs": 2,
# "client": {
#     "cluster_type": "local",
#     "params": {
#         "n_workers": 4,
#         "threads_per_worker": 4,
#         "memory_limit": "8GB"
#     }
# }
# ```

# %%
pipeline.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "sample_data": "benthic_csv",
#         "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#         "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#         "metadata_type": "CSV_FILE",
#         "image_type": "PNG",
#         "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#         "is_remote": false,
#         "output_is_remote": false,
#         "output_path": "output",
#         "n_jobs": 2,
#         "client": {
#             "cluster_type": "local",
#             "params": {
#                 "n_workers": 4,
#                 "threads_per_worker": 4,
#                 "memory_limit": "8GB"
#             }
#         },
#         "track_changes": false,
#         "rename": null,
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "mode": "fixed",
#                 "test": false,
#                 "params": {
#                     "value": 20,
#                     "raise_error": false
#                 }
#             }
#         ],
#         "convert": [
#             {
#                 "name": "convert",
#                 "step_name": "convert",
#                 "mode": "bits",
#                 "test": false,
#                 "params": {
#                     "output_bits": 8,
#                     "raise_error": false
#                 }
#             }
#         ]
#     },
#     "steps": [
#         {
#             "name": "colour_alteration",
#             "step_name": "colour",
#             "mode": "colour_alteration",
#             "test": false,
#             "params": {
#                 "method": "white_balance",
#                 "raise_error": false
#             }
#         },
#         {
#             "name": "gaussian_blur",
#             "step_name": "colour",
#             "mode": "gaussian_blur",
#             "test": false,
#             "params": {
#                 "sigma": 1.0,
#                 "raise_error": false
#             }
#         },
#         {
#             "name": "sharpen",
#             "step_name": "colour",
#             "mode": "sharpen",
#             "test": false,
#             "params": {
#                 "alpha": 1.5,
#                 "beta": -0.5,
#                 "raise_error": false
#             }
#         },
#         {
#             "name": "contrast",
#             "step_name": "colour",
#             "mode": "contrast",
#             "test": false
#         }
#     ]
# }

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
#         <div style="display: flex; flex-wrap: wrap; align-items: center;">
#
#         <div id="general" title="Click to see more information" class="square"
#             style="float:left; cursor: pointer; padding: 10px;
#             width: max-content; height: 80px; margin: 10px;
#             border: 1px solid #000; text-align: center; line-height: 80px;"
#             onclick="showParameters('general')">
#             <h2 style="font-size:20px;">Raw</h2>
#             <h2 style="font-size:13px;">Type: Open</h2>
#         </div>
#         <div style="float:left; width: 50px; height: 80px; margin: 10px; text-align: center; line-height: 80px;">&#10132;</div>
#                 <div id="step_0" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_0')">
#                     <h2 style="font-size:20px;">Colour_alteration</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_1" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_1')">
#                     <h2 style="font-size:20px;">Gaussian_blur</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_2" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_2')">
#                     <h2 style="font-size:20px;">Sharpen</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#                     <div style="float:left; width: 50px; height: 80px;
#                         margin: 10px; text-align: center; line-height: 80px;">
#                         &#10132;
#                     </div>
#
#                 <div id="step_3" title="Click to see more information"
#                     class="square" style="cursor: pointer; float:left;
#                     padding: 10px; width: max-content; height: 80px;
#                     margin: 10px; border: 1px solid #000; text-align: center;
#                     line-height: 80px;" onclick="showParameters('step_3')">
#                     <h2 style="font-size:20px;">Contrast</h2>
#                     <h2 style="font-size:13px;">Type: Colour</h2>
#                 </div>
#
#         </div>
#         <div id="parameters" style="padding: 10px; margin: 10px;">
#                 <div id="parameters_step_0" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "colour_alteration",
#     "step_name": "colour",
#     "mode": "colour_alteration",
#     "test": false,
#     "params": {
#         "method": "white_balance",
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_1" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "gaussian_blur",
#     "step_name": "colour",
#     "mode": "gaussian_blur",
#     "test": false,
#     "params": {
#         "sigma": 1.0,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_2" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "sharpen",
#     "step_name": "colour",
#     "mode": "sharpen",
#     "test": false,
#     "params": {
#         "alpha": 1.5,
#         "beta": -0.5,
#         "raise_error": false
#     }
# }</pre>
#                 </div>
#
#                 <div id="parameters_step_3" class="parameters"
#                     style="display: none;">
#                     <pre>{
#     "name": "contrast",
#     "step_name": "colour",
#     "mode": "contrast",
#     "test": false
# }</pre>
#                 </div>
#
#             <div id="parameters_general" class="parameters" style="display: none;">
#                 <pre>{
#     "name": "raw",
#     "step_name": "open",
#     "sample_data": "benthic_csv",
#     "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#     "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#     "metadata_type": "CSV_FILE",
#     "image_type": "PNG",
#     "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#     "is_remote": false,
#     "output_is_remote": false,
#     "output_path": "output",
#     "n_jobs": 2,
#     "client": {
#         "cluster_type": "local",
#         "params": {
#             "n_workers": 4,
#             "threads_per_worker": 4,
#             "memory_limit": "8GB"
#         }
#     },
#     "track_changes": false,
#     "rename": null,
#     "sampling": [
#         {
#             "name": "sampling",
#             "step_name": "sampling",
#             "mode": "fixed",
#             "test": false,
#             "params": {
#                 "value": 20,
#                 "raise_error": false
#             }
#         }
#     ],
#     "convert": [
#         {
#             "name": "convert",
#             "step_name": "convert",
#             "mode": "bits",
#             "test": false,
#             "params": {
#                 "output_bits": 8,
#                 "raise_error": false
#             }
#         }
#     ]
# }</pre>
#             </div>
#         </div>
#         <script>
#             function showParameters(id) {
#                 // Hide all parameter sections
#                 var currentTarget = document.getElementById(id);
#                 var square = document.getElementsByClassName('square');
#                 var allParams = document.getElementsByClassName('parameters');
#                 var selectedParams = document.getElementById('parameters_' + id);
#                 var idWasVisible = false;
#                 if (selectedParams) {
#                     var idWasVisible = selectedParams.style.display === 'block';
#                 }
#                 for (var i = 0; i < square.length; i++) {
#                     square[i].style.color = 'black';
#                 }
#                 for (var i = 0; i < allParams.length; i++) {
#                     allParams[i].style.display = 'none';
#                 }
#                 // Show the selected parameter section
#                 if (selectedParams) {
#                     if (idWasVisible) {
#                         selectedParams.style.display = 'none';
#                         currentTarget.style.color = 'black';
#                     } else {
#                         selectedParams.style.display = 'block';
#                         currentTarget.style.color = 'red';
#                     }
#                 }
#             }
#         </script>

# %% [markdown]
# ## Run the pipeline
#
# You can follow the workers on the dashboard provided

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:24 | Processing images using Dask client using the following dashboard link: http://127.0.0.1:8787/status
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:24 | Running step 0: raw - OpenLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:27 | Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:27 | Running step 1: colour_alteration - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Running step 2: gaussian_blur - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Running step 3: sharpen - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:28 | Running step 4: contrast - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-02-12 13:34:29 | Step 4 completed

# %% [markdown]
# ## See the images
#
# Because you include in the configuration file the argument "track_changes: False", only the output of the last layer will be saved.
# This is a strategy to save memory when you are processing a big dataset

# %%
pipeline.images
# Out:
# Step: raw
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Step: colour_alteration
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Step: gaussian_blur
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Step: sharpen
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Image: None
# Step: contrast
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
# Image: dask.array<array, shape=(128, 128, 3), dtype=uint8, chunksize=(128, 128, 3), chunktype=numpy.ndarray>
